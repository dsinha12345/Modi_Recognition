# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/admin-dsinha1/Desktop/Modi_Recognition/classification_report.csv')

# %%
df = df.round(2)

# Display the rounded DataFrame
print(df.head())
# Out:
#   Unnamed: 0  precision  recall  f1-score  support
# 0    Class 0       0.96    0.95      0.95   2041.0
# 1    Class 1       0.95    0.96      0.96   2038.0
# 2    Class 2       0.98    0.95      0.96   2001.0
# 3    Class 3       0.97    0.95      0.96   2040.0
# 4    Class 4       0.79    0.71      0.75   2053.0

# %%
df
# Out:
#       Unnamed: 0  precision  recall  f1-score    support
# 0        Class 0       0.96    0.95      0.95    2041.00
# 1        Class 1       0.95    0.96      0.96    2038.00
# 2        Class 2       0.98    0.95      0.96    2001.00
# 3        Class 3       0.97    0.95      0.96    2040.00
# 4        Class 4       0.79    0.71      0.75    2053.00
# 5        Class 5       0.74    0.84      0.79    2012.00
# 6        Class 6       0.95    0.96      0.96    2079.00
# 7        Class 7       0.98    0.97      0.97    2031.00
# 8        Class 8       0.95    0.95      0.95    2005.00
# 9        Class 9       0.98    0.98      0.98    1953.00
# 10      Class 10       0.90    0.94      0.92    2002.00
# 11      Class 11       0.89    0.95      0.92    2017.00
# 12      Class 12       0.90    0.90      0.90    2095.00
# 13      Class 13       0.95    0.95      0.95    2066.00
# 14      Class 14       0.96    0.97      0.96    2018.00
# ...

# %%
df.to_excel('/Users/admin-dsinha1/Desktop/Modi_Recognition/classification_report.xlsx', index = False)

# %%
# !pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
